# %%
### Variables ###

my_string_variable = "My String Variable"
print(my_string_variable)

my_int_variable = 5
print(my_int_variable)

my_int_to_str_variable = str(my_int_variable)
print(my_int_to_str_variable)
print(type(my_int_to_str_variable))

my_bool_variable = False
print(my_bool_variable)


# Concatenación de variables en un print
print(my_string_variable, my_int_to_str_variable, my_bool_variable)
print("Este es el valor de:", my_bool_variable)

# Algunas funciones del sistema
print(len(my_string_variable)) # len sirve para contar los caracteres de la variable, incluso los espacios

# Variables en una sola línea. ¡Cuidado con abusar de esta sintaxis!
name, surname, alias, age = "cristian", "rodriguez hernandez", 'cris', 35
print("Me llamo:", name, surname, ". Mi edad es:",
     age, ". Y mi alias es:", alias)

# Inputs
name = input('¿Cuál es tu nombre? ')
age = input('¿Cuántos años tienes? ')
print(name)
print(age)

# Cambiamos su tipo
name = 17
age = "andres"
print(name)
print(age)

# ¿Forzamos el tipo?
address: str = "Mi dirección"
address = True
address = 5
address = 1.2
print(type(address))
# Out:
# My String Variable
# 5
# 5
# <class 'str'>
# False
# My String Variable 5 False
# Este es el valor de: False
# 18
# Me llamo: Fermín García Estrada . Mi edad es: 35 . Y mi alias es: Profe
# ¿Cuál es tu nombre? roberto
# ¿Cuántos años tienes? 100
# roberto
# 100
# 35
# Carlos
# <class 'float'>
